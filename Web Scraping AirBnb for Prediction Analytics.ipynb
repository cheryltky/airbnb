# %% [markdown]
# # Web parsing with Python and Beautiful Soup

# %% [markdown]
# # Airbnb prediction modelling project
# ### Objective: To create a data science project, I scraped the data instead of downloading it. Then modelling to predict price of listing based on features of the listing. The end goal is to create a chrome extension for the airbnb page to determine if a listing is overpriced or worth the value based on filters.

# %% [markdown]
# ### 1,  Get the HTML

# %%
#!pip install requests
import requests
#!pip install IPython

# %%
airbnb_url = 'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click'

# %%
answer = requests.get(airbnb_url)

# %%
# what you can do with an answer
print(answer.airbnb_url)
print(answer.status_code)
print(answer.reason)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-db9720992b38> in <module>
#       1 # what you can do with an answer
# ----> 2 print(answer.airbnb_url)
#       3 print(answer.status_code)
#       4 print(answer.reason)
#
# AttributeError: 'Response' object has no attribute 'airbnb_url'

# %%
print(answer.content)
# Out:
# b'<!doctype html>\n<html data-is-hyperloop="true"><script>window.sherlock_firstbyte = window.performance && window.performance.timing ? window.performance.timing.responseStart : Number(new Date());</script><script>!function(){"use strict";var n=window;const e="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789+/",o=new RegExp(`^\\\\d{10}_[${e}]{16}$`);const t=/(?:^| )bev=(.*?)(?:;|$)/;let c=!1;function i(){if(c||"undefined"==typeof document)return null;c=!0;const n=(document.cookie||"").match(t);if(!n||2!==n.length)return null;const e=decodeURIComponent(n[1]);return function(n){return o.test(n)}(e)?e:null}!function(){try{if(n.bev=n.bev||i(),!n.bev){const o=function(){const n=[];for(let o=0;o<16;o+=1)n.push(e[Math.floor(Math.random()*e.length)]);return`${Math.floor(Date.now()/1e3)}_${n.join("")}`}();!function(n){const{hostname:e}=document.location,o="."+e.slice(e.indexOf("airbnb.")),t=new Date;t.setDate(t.getDate()+730),document.cookie=["bev="+encodeURIComponent(n),"expires="+t.toUTCString(),"path=/","domain="+o,"secure"].join("; ")}(o),n.bev=o}}catch(n){window.console&&console.error("Could not set bev cookie:",n)}}()}();\n</script><script>(function() {\n  var pgRequest = new XMLHttpRequest();\n  var diffStamp = Date.now().toString() + Math.random().toString().substring(2);\n  pgRequest.open(\'GET\', \'/pg_pixel?r=\' + encodeURIComponent(document.referrer || \'\') + \'&diff=\' + diffStamp, true);\n  pgRequest.send();\n})()</script><script>(function(){function a(){return"undefined"!=typeof window&&window.location&&window.location.host?window.location.host.replace(":","-"):"unknown"}function b(){return"xxxxxxxx-xxxx-4xxx-yxxx-xxxxxxxxxxxx".replace(/[xy]/g,a=>{const b=0|16*parseFloat(`0.${(Math.random()+"").replace("0.","")}${new Date().getTime()}`),c="x"===a?b:8|3&b;return c.toString(16)})}function c(){var a,b,c,d;return null!==(a=null===(b=navigator)||void 0===b||null===(c=b.serviceWorker)||void 0===c||null===(d=c.controller)||void 0===d?void 0:d.scriptURL)&&void 0!==a?a:"none"}window._bufferedErrors=[];const d=window.onerror;window.onerror=(a,b,c,e,f)=>{d&&d.call(window,a,b,c,e,f),window._bufferedErrors&&window._bufferedErrors.push([a,b,c,e,f])},window.addEventListener("load",()=>{if(!window._errorReportingInitialized){const e=window._bufferedErrors||[];if(window.fetch&&0<e.length){var d;window.fetch("/tracking/jitney/logging/messages",{body:JSON.stringify([{trackingjs_logging_version:"0.6.0",uuid:b(),event_name:"jitney_universal_error",schema:"com.airbnb.jitney.event.logging.Universal:UniversalErrorEvent:1.0.0",event_data:{context:{timestamp:Date.now(),source:"hyperloop",platform:"wide-web",user_agent:null===(d=navigator)||void 0===d?void 0:d.userAgent,extra_data:{serviceworker:c(),host:a()}},event_name:"jitney_universal_error",schema:"com.airbnb.jitney.event.logging.Universal:UniversalErrorEvent:1.0.0",message:"UnhandledBufferedError",level:"fatal",exceptions:e.map(a=>({message:a[0],type:"UnhandledBufferedError",stacktrace:{frames:[{column:a[3]||0,filename:a[1]||"[unknown]",function_name:"[unknown]",line:a[2]||0}]}}))}}]),method:"POST"})}}})})();</script><script>\n// FID init code.\n(function(a,b){function c(a){l.push(a),f()}function d(a,b){i||(i=b,j=a,k=new Date,f())}function e(){i&&(i=null,j=null,k=null)}function f(){0<=j&&j<k-n&&(l.forEach(a=>{a(j,i)}),l=[])}function g(c,e){function f(){d(c,e),h()}function g(){h()}function h(){b(o,f,m),b(p,g,m)}a(o,f,m),a(p,g,m)}function h(a){if(a.cancelable){const b=1e12<a.timeStamp,c=b?new Date:performance.now(),e=c-a.timeStamp;"pointerdown"===a.type?g(e,a):d(e,a)}}let i,j,k,l=[];const m={passive:!0,capture:!0},n=new Date,o="pointerup",p="pointercancel";(function(a){["click","mousedown","keydown","touchstart","pointerdown"].forEach(b=>{a(b,h,m)})})(a),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=c,self.perfMetrics.clearFirstInputDelay=e})(addEventListener,removeEventListener);\n// FCP init code.\n(function(a){function b(){return!!document.body&&nul ...

# %%
# We need to use something else to navigate through the HTML chunk above

# %% [markdown]
# ## 2. Use BS

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(answer.content, 'html.parser')

# %% [markdown]
# ### 3. Scrape Airbnb Webpage

# %%
airbnb_url = 'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click'

# %%
# Now I can parse the url above using BS
soup = BeautifulSoup(requests.get(airbnb_url).content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-is-hyperloop="true">
#  <script>
#   window.sherlock_firstbyte = window.performance && window.performance.timing ? window.performance.timing.responseStart : Number(new Date());
#  </script>
#  <script>
#   !function(){"use strict";var n=window;const e="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789+/",o=new RegExp(`^\\d{10}_[${e}]{16}$`);const t=/(?:^| )bev=(.*?)(?:;|$)/;let c=!1;function i(){if(c||"undefined"==typeof document)return null;c=!0;const n=(document.cookie||"").match(t);if(!n||2!==n.length)return null;const e=decodeURIComponent(n[1]);return function(n){return o.test(n)}(e)?e:null}!function(){try{if(n.bev=n.bev||i(),!n.bev){const o=function(){const n=[];for(let o=0;o<16;o+=1)n.push(e[Math.floor(Math.random()*e.length)]);return`${Math.floor(Date.now()/1e3)}_${n.join("")}`}();!function(n){const{hostname:e}=document.location,o="."+e.slice(e.indexOf("airbnb.")),t=new Date;t.setDate(t.getDate()+730),document.cookie=["bev="+encodeURIComponent(n),"expires="+t.toUTCString(),"path=/","domain="+o,"secure"].join("; ")}(o),n.bev=o}}catch(n){window.console&&console.error("Could not set bev cookie:",n)}}()}();
#  </script>
#  <script>
#   (function() {
#   var pgRequest = new XMLHttpRequest();
#   var diffStamp = Date.now().toString() + Math.random().toString().substring(2);
#   pgRequest.open('GET', '/pg_pixel?r=' + encodeURIComponent(document.referrer || '') + '&diff=' + diffStamp, true);
#   pgRequest.send();
# })()
#  </script>
#  <script>
#   (function(){function a(){return"undefined"!=typeof window&&window.location&&window.location.host?window.location.host.replace(":","-"):"unknown"}function b(){return"xxxxxxxx-xxxx-4xxx-yxxx-xxxxxxxxxxxx".replace(/[xy]/g,a=>{const b=0|16*parseFloat(`0.${(Math.random()+"").replace("0.","")}${new Date().getTime()}`),c="x"===a?b:8|3&b;return c.toString(16)})}function c(){var a,b,c,d;return null!==(a=null===(b=navigator)||void 0===b||null===(c=b.serviceWorker)||void 0===c||null===(d=c.controller)||void 0===d?void 0:d.scriptURL)&&void 0!==a?a:"none"}window._bufferedErrors=[];const d=window.onerror;window.onerror=(a,b,c,e,f)=>{d&&d.call(window,a,b,c,e,f),window._bufferedErrors&&window._bufferedErrors.push([a,b,c,e,f])},window.addEventListener("load",()=>{if(!window._errorReportingInitialized){const e=window._bufferedErrors||[];if(window.fetch&&0<e.length){var d;window.fetch("/tracking/jitney/logging/messages",{body:JSON.stringify([{trackingjs_logging_version:"0.6.0",uuid:b(),event_name:"jitney_universal_error",schema:"com.airbnb.jitney.event.logging.Universal:UniversalErrorEvent:1.0.0",event_data:{context:{timestamp:Date.now(),source:"hyperloop",platform:"wide-web",user_agent:null===(d=navigator)||void 0===d?void 0:d.userAgent,extra_data:{serviceworker:c(),host:a()}},event_name:"jitney_universal_error",schema:"com.airbnb.jitney.event.logging.Universal:UniversalErrorEvent:1.0.0",message:"UnhandledBufferedError",level:"fatal",exceptions:e.map(a=>({message:a[0],type:"UnhandledBufferedError",stacktrace:{frames:[{column:a[3]||0,filename:a[1]||"[unknown]",function_name:"[unknown]",line:a[2]||0}]}}))}}]),method:"POST"})}}})})();
#  </script>
#  <script>
#   // FID init code.
# (function(a,b){function c(a){l.push(a),f()}function d(a,b){i||(i=b,j=a,k=new Date,f())}function e(){i&&(i=null,j=null,k=null)}function f(){0<=j&&j<k-n&&(l.forEach(a=>{a(j,i)}),l=[])}function g(c,e){function f(){d(c,e),h()}function g(){h()}function h(){b(o,f,m),b(p,g,m)}a(o,f,m),a(p,g,m)}function h(a){if(a.cancelable){const b=1e12<a.timeStamp,c=b?new Date:performance.now(),e=c-a.timeStamp;"pointerdown"===a.type?g(e,a):d(e,a)}}let i,j,k,l=[];const m={passive:!0,capture:!0},n=new Date,o="pointerup",p="pointercancel";(function(a){["click","mousedown","keydown","touchstart","pointerdown"].forEach(b=>{a(b,h,m)})})(a),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=c,self.perfMetrics.clearFirstInputDelay=e})(addEventListener,removeEventListener);
# // FCP init code.
# (function(a){function b(){return!!document.body&&null!==document.createNodeIterator(document.body,NodeFilter.SHOW_TEXT,function(a){return!!a&&/[^\s]/.test(a.nodeValue)&&"SCRIPT"!==a.parentNode.tagName&&"STYLE"!==a.parentNode.tagName&&0<a.parentNode.offsetHeight},!1).nextNode()}function c(){return null!==document.querySelector("input[placeholder]")}function d(){return b()||c()?void a(function(){const a=performance.now();f?f(a):g=a,performance.measure&&performance.measure("TTFCP")}):void a(d)}function e(a){g?a(g):f=a}let f,g;a(d),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstContentfulPaint=e})(requestAnimationFrame);
# // TTFMP Polyfill code.
# (function(a){function b(){const c=document.getElementById(i);h=0,c?g===c?e=a(b):"IMG"!==c.tagName||c.complete?a(function(){const a=performance.now();g=c,f?f(a):h=a,performance.measure&&performance.measure("TTFMP")}):e=a(b):e=a(b)}function c(a){h?a(h):f=a}function d(){cancelAnimationFrame(e)}let e,f,g,h;const i="FMP-target";e=a(b),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstMeaningfulPaint=c,self.perfMetrics.startSearchingForFirstMeaningfulPaint=function(){g=document.getElementById(i),b()},self.perfMetrics.stopSearchingForFirstMeaningfulPaint=d})(requestAnimationFrame);
#  </script>
#  <meta charset="utf-8"/>
#  <meta content="en-AU" name="locale"/>
#  <meta content="notranslate" name="google"/>
#  <meta content="authenticity_token" id="csrf-param-meta-tag" name="csrf-param"/>
#  <meta content="" id="csrf-token-meta-tag" name="csrf-token"/>
#  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#  <meta content="" id="english-canonical-url"/>
#  <meta content="on" name="twitter:widgets:csp"/>
#  <link href="/opensearch.xml" rel="search" title="Airbnb" type="application/opensearchdescription+xml"/>
#  <link href="/manifest.json" rel="manifest"/>
#  <meta content="yes" name="mobile-web-app-capable"/>
#  <meta content="yes" name="apple-mobile-web-app-capable"/>
#  <meta content="Airbnb" name="application-name"/>
#  <meta content="Airbnb" name="apple-mobile-web-app-title"/>
#  <meta content="#ffffff" name="theme-color"/>
#  <meta content="#ffffff" name="msapplication-navbutton-color"/>
#  <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
#  <meta content="/?utm_source=homescreen" name="msapplication-starturl"/>
#  <link href="https://a0.muscache.com/airbnb/static/icons/apple-touch-icon-76x76-3b313d93b1b5823293524b9764352ac9.png" rel="apple-touch-icon"/>
#  <link href="https://a0.muscache.com/airbnb/static/icons/apple-touch-icon-76x76-3b313d93b1b5823293524b9764352ac9.png" rel="apple-touch-icon" sizes="76x76"/>
#  <link href="https://a0.muscache.com/airbnb/static/icons/apple-touch-icon-120x120-52b1adb4fe3a8f825fc4b143de12ea4b.png" rel="apple-touch-icon" sizes="120x120"/>
#  <link href="https://a0.muscache.com/airbnb/static/icons/apple-touch-icon-152x152-7b7c6444b63d8b6ebad9dae7169e5ed6.png" rel="apple-touch-icon" sizes="152x152"/>
#  <link href="https://a0.muscache.com/airbnb/static/icons/apple-touch-icon-180x180-bcbe0e3960cd084eb8eaf1353cf3c730.png" rel="apple-touch-icon" sizes="180x180"/>
#  <link href="https://a0.muscache.com/airbnb/static/icons/android-icon-192x192-c0465f9f0380893768972a31a614b670.png" rel="icon" sizes="192x192"/>
#  <link href="https://a0.muscache.com/airbnb/static/logotype_favicon-21cc8e6c6a2cca43f061d2dcabdf6e58.ico" rel="shortcut icon" sizes="76x76" type="image/x-icon"/>
#  <link color="#FF5A5F" href="https://a0.muscache.com/airbnb/static/icons/airbnb-0611901eac33ccfa5e93d793a2e21f09.svg" rel="mask-icon"/>
#  <script data-is-async-scripts="true" id="data-is-async-scripts" type="application/json">
#   false
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/runtime-6ff17b58.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/shims_post_modules-367d670d.js">
#  </script>
#  <script crossorigin="anonymous" defer="" nomodule="" src="https://a0.muscache.com/airbnb/static/packages/shims_pre_modules-e5f432c9.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/moment/en-au-edccab67.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/core-guest-loop/phrases_manifest/en-AU/core-guest-spa/hyperloop/index-f86bb4b332.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/moment-f651b112.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/cfb1-9be0c07f.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/0143-c15bcf41.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/0421-e1cd125a.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/28b0-4d58201c.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/4fda-f21eb3aa.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/initializers-9d420d05.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/common-7d465077.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/d54e-6f5ef2c1.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/Corgi-App-aa0291e7.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/22fe-5001651f.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/df3e-9c578f4b.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/c682-3a614494.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/V3SearchContainer-6779ca9e.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/lodash-2e8abd7a.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/5f89-bef5c8a3.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/0740-2a76caf4.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/ef61-9ac15cd6.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/67a2-fe2ddf55.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/1614-14624cde.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/b9c5-32d0b843.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/9ee0-f1f06b70.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/8b75-5dcf12ba.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/6297-1e31b6fb.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/bea9-37554dd8.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/2266-02b7e328.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/34b05-d8589644.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/053d-a5ec3cce.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/d74d-e3357801.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/Explore-SearchContainer_async-405d88d8.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/react-be8bdf6e.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/aphrodite-f2ecca08.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/4d19-164eaac6.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/2986-47dbddcc.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/5324-368093ca.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/979f-8903b76b.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/0821-321f9069.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/d2a5-db52f6da.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/93ef-1cc6c7d7.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/40c9-f0425492.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/94b2-c23a7b1b.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/b338-edc4a9b7.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/6285-6415d05a.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/f4f6-b81ffaf1.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/26fa-826a3e6a.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/e645-93f99028.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/f2f8-f271777d.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/7ed2-350c0d0b.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/0475-8c7c0924.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/c6ec-d40b20ad.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/914b-f6529d9d.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/b3c3-63c274bc.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/ac50-a20f7efb.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/48b0-040e7c81.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/aa2d-df7070b8.js">
#  </script>
#  <script crossorigin="anonymous" defer="" src="https://a0.muscache.com/airbnb/static/packages/core-guest-spa/hyperloop/index-b6689b43.js">
#  </script>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/1940-43c866ca.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/niobe-minimalist-client-973063fd.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/f8fc-6e708414.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/niobe-apollo-client-247635f1.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/Header-Query-c2eb6f5a.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/Explore-V3Prepare-f608dd3c.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/3e42-2b63d452.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/2824-2279e0bb.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/b45b-d4fefaf3.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/34b0-1ad8e94d.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/7a36-19017208.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/8dd3-a9e1963a.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/8d13-8525b1f1.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/a7ed-b4fc0d89.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/b12d-2085a827.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/8359-5b234c3e.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/simple-nav-header-1fd50239.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/e301-9e4baac1.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/dls-CarouselController-7bcbe9a8.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/5bb5-47b16504.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/a084-93d6f1c6.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/9698-a64a926d.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/0128-9ecc6086.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/2b8e-ab5e354a.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/c232-ffd104e8.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/d465-2ac840f4.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/6215-3eadc2b6.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/explore-original_explore_Listings-51c7e323.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/explore-original_explore_DestinationRecommendations-c5e49bb2.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/ExploreFooter-HomeSearchFooter-7c4e1c88.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/7254-055a2739.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/d235-3c788e85.js" rel="prefetch"/>
#  <link as="script" crossorigin="anonymous" href="https://a0.muscache.com/airbnb/static/packages/simple-nav-Footer-d031bb43.js" rel="prefetch"/>
#  <meta content="138566025676" property="fb:app_id"/>
#  <meta content="Airbnb" property="og:site_name"/>
#  <meta content="en_GB" property="og:locale"/>
#  <meta property="og:url"/>
#  <meta content="Airbnb® | Queensland - Holiday Rentals &amp; Places to Stay" property="og:title"/>
#  <meta content="Apr 29, 2021 - Rent from people in Queensland, Australia from $26 AUD/night. Find unique places to stay with local hosts in 191 countries. Belong anywhere with Airbnb." property="og:description"/>
#  <meta content="website" property="og:type"/>
#  <meta content="https://a0.muscache.com/airbnb/static/logos/trips-og-1280x630-9de9c338cc3fd9b5663fb80be0cbe8c2.jpg" property="og:image"/>
#  <link href="android-app://com.airbnb.android/airbnb/s/Queensland--Australia" rel="alternate"/>
#  <meta content="noindex, nofollow" name="robots"/>
#  <meta content="Apr 29, 2021 - Rent from people in Queensland, Australia from $26 AUD/night. Find unique places to stay with local hosts in 191 countries. Belong anywhere with Airbnb." name="description"/>
#  <link href="https://a0.muscache.com/airbnb/static/packages/dls/dls-lite_cereal-d9f6fdb2a0dd4a18c37f8ee01de8ec3d.css" media="all" rel="stylesheet" type="text/css"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <link media="all" rel="stylesheet" type="text/css"/>
#  <title>
#   Airbnb® | Queensland - Holiday Rentals &amp; Places to Stay
#  </title>
#  <meta name="twitter:card"/>
#  <meta content="Airbnb® | Queensland - Holiday Rentals &amp; Places to Stay" name="twitter:title"/>
#  <meta content="@airbnb_au" name="twitter:site"/>
#  <meta content="Airbnb" name="twitter:app:name:iphone"/>
#  <meta content="Airbnb" name="twitter:app:name:ipad"/>
#  <meta content="Airbnb" name="twitter:app:name:googleplay"/>
#  <meta content="401626263" name="twitter:app:id:iphone"/>
#  <meta content="401626263" name="twitter:app:id:ipad"/>
#  <meta content="com.airbnb.android" name="twitter:app:id:googleplay"/>
#  <meta name="twitter:url"/>
#  <meta content="Apr 29, 2021 - Rent from people in Queensland, Australia from $26 AUD/night. Find unique places to stay with local hosts in 191 countries. Belong anywhere with Airbnb." name="twitter:description"/>
#  <meta name="twitter:image"/>
#  <body class="with-new-header">
#   <a class="screen-reader-only screen-reader-only-focusable skip-to-content" data-hook="skip-to-content" href="#site-content">
#    Skip to content
#   </a>
#   <div id="smart-banner">
#   </div>
#   <noscript>
#    <div class="alert alert-with-icon alert-error no-js-alert" data-nosnippet="true">
#     <i class="icon alert-icon icon-alert-alt">
#     </i>
#     We’re sorry, some parts of the Airbnb website don’t work properly without JavaScript enabled.
#    </div>
#   </noscript>
#   <div class="flash-container" id="flash-container">
#   </div>
#   <div id="education-overlay-root">
#   </div>
#   <style data-aphrodite="true">
#    ._16grqhk{position:relative !important;min-height:100vh !important;}._siy8gh{display:none !important;}@media (min-width: 744px){._siy8gh{display:block !important;}}._xca6kx{display:block !important;}@media (min-width: 744px){._xca6kx{display:none !important;}}._1gw6tte::before{display:-webkit-box !important;display:-moz-box !important;display:-ms-flexbox !important;display:-webkit-flex !important;display:flex !important;content:'' !important;}._1gw6tte::after{display:-webkit-box !important;display:-moz-box !important;display:-ms-flexbox !important;display:-webkit-flex !important;display:flex !important;content:'' !important;}._1egkn2c4{height:80px !important;position:fixed !important;left:0px !important;width:100% !important;z-index:100 !important;--header-brand-color:#FF385C !important;}._1egkn2c4::before{background-image:-webkit-linear-gradient(to bottom, #000, rgba(0, 0, 0, 0)) !important;background-image:-moz-linear-gradient(to bottom, #000, rgba(0, 0, 0, 0)) !important;background-image:linear-gradient(to bottom, #000, rgba(0, 0, 0, 0)) !important;content:"" !important;height:140% !important;left:0px !important;opacity:0 !important;pointer-events:none !important;position:absolute !important;top:0px !important;width:100% !important;z-index:0 !important;-webkit-transition:150ms opacity ease !important;-moz-transition:150ms opacity ease !important;transition:150ms opacity ease !important;}@media (prefers-reduced-motion: reduce){._1egkn2c4::before{-webkit-transition:none !important;-moz-transition:none !important;transition:none !important;}}._1egkn2c4::after{box-shadow:rgba(0, 0, 0, 0.08) 0px 1px 12px !important;-webkit-transform-origin:50% 0% !important;-ms-transform-origin:50% 0% !important;transform-origin:50% 0% !important;-webkit-transition-duration:150ms !important;transition-duration:150ms !important;-webkit-transition-property:opacity, -webkit-transform, transform !important;-moz-transition-property:opacity, transform !important;transition-property:opacity, -ms-transform, -webkit-transform, transform !important;-webkit-transition-timing-function:ease !important;transition-timing-function:ease !important;background:#FFFFFF !important;content:"" !important;height:100% !important;left:0px !important;position:absolute !important;top:0px !important;width:100% !important;z-index:0 !important;opacity:1 !important;}@media (prefers-reduced-motion: reduce){._1egkn2c4::after{-webkit-transition:none !important;-moz-transition:none !important;transition:none !important;}}._fbarm7d{-webkit-box-align:center !important;-ms-flex-align:center !important;-webkit-box-pack:justify !important;-ms-flex-pack:justify !important;-webkit-justify-content:space-between !important;justify-content:space-between !important;-webkit-align-items:center !important;align-items:center !important;display:-webkit-box !important;display:-moz-box !important;display:-ms-flexbox !important;display:-webkit-flex !important;display:flex !important;height:100% !important;position:relative !important;width:100% !important;z-index:1 !important;padding:0 24px !important;}._otdka{-webkit-flex:0 0 auto !important;-ms-flex:0 0 auto !important;flex:0 0 auto !important;}@media (min-width: 950px){._otdka{-webkit-flex:1 0 140px !important;-ms-flex:1 0 140px !important;flex:1 0 140px !important;}}._2ox3s8{-webkit-flex:0 1 auto !important;-ms-flex:0 1 auto !important;flex:0 1 auto !important;min-width:0px !important;padding:0 24px !important;}@media (min-width: 950px){._2ox3s8{text-align:center !important;}}._19h9w7f{-webkit-flex:1 0 auto !important;-ms-flex:1 0 auto !important;flex:1 0 auto !important;}@media (min-width: 950px){._19h9w7f{-webkit-flex:1 0 140px !important;-ms-flex:1 0 140px !important;flex:1 0 140px !important;}}._qkr85q{height:80px !important;}._o6689fn{-webkit-box-align:center !important;-ms-flex-align:center !important;outline:none !important;-webkit-align-items:center !important;align-items:center !important;display:-webkit-inline-box !important;display ...
#   </style>
#   <div data-application="true">
#    <div dir="ltr">
#     <div>
#      <div style="--page-shell-max-content-width:none">
#       <div class="_16grqhk">
#        <div class="_siy8gh">
#         <div class="_1gw6tte">
#          <header class="_1egkn2c4">
#           <div class="_fbarm7d">
#            <div class="_otdka">
#             <a aria-label="Airbnb homepage" class="_o6689fn" href="/">
#              <div class="_1grlqto">
#               <svg fill="currentcolor" height="32" style="display:block" width="102">
#                <path d="M29.24 22.68c-.16-.39-.31-.8-.47-1.15l-.74-1.67-.03-.03c-2.2-4.8-4.55-9.68-7.04-14.48l-.1-.2c-.25-.47-.5-.99-.76-1.47-.32-.57-.63-1.18-1.14-1.76a5.3 5.3 0 00-8.2 0c-.47.58-.82 1.19-1.14 1.76-.25.52-.5 1.03-.76 1.5l-.1.2c-2.45 4.8-4.84 9.68-7.04 14.48l-.06.06c-.22.52-.48 1.06-.73 1.64-.16.35-.32.73-.48 1.15a6.8 6.8 0 007.2 9.23 8.38 8.38 0 003.18-1.1c1.3-.73 2.55-1.79 3.95-3.32 1.4 1.53 2.68 2.59 3.95 3.33A8.38 8.38 0 0022.75 32a6.79 6.79 0 006.75-5.83 5.94 5.94 0 00-.26-3.5zm-14.36 1.66c-1.72-2.2-2.84-4.22-3.22-5.95a5.2 5.2 0 01-.1-1.96c.07-.51.26-.96.52-1.34.6-.87 1.65-1.41 2.8-1.41a3.3 3.3 0 012.8 1.4c.26.4.45.84.51 1.35.1.58.06 1.25-.1 1.96-.38 1.7-1.5 3.74-3.21 5.95zm12.74 1.48a4.76 4.76 0 01-2.9 3.75c-.76.32-1.6.41-2.42.32-.8-.1-1.6-.36-2.42-.84a15.64 15.64 0 01-3.63-3.1c2.1-2.6 3.37-4.97 3.85-7.08.23-1 .26-1.9.16-2.73a5.53 5.53 0 00-.86-2.2 5.36 5.36 0 00-4.49-2.28c-1.85 0-3.5.86-4.5 2.27a5.18 5.18 0 00-.85 2.21c-.13.84-.1 1.77.16 2.73.48 2.11 1.78 4.51 3.85 7.1a14.33 14.33 0 01-3.63 3.12c-.83.48-1.62.73-2.42.83a4.76 4.76 0 01-5.32-4.07c-.1-.8-.03-1.6.29-2.5.1-.32.25-.64.41-1.02.22-.52.48-1.06.73-1.6l.04-.07c2.16-4.77 4.52-9.64 6.97-14.41l.1-.2c.25-.48.5-.99.76-1.47.26-.51.54-1 .9-1.4a3.32 3.32 0 015.09 0c.35.4.64.89.9 1.4.25.48.5 1 .76 1.47l.1.2c2.44 4.77 4.8 9.64 7 14.41l.03.03c.26.52.48 1.1.73 1.6.16.39.32.7.42 1.03.19.9.29 1.7.19 2.5zM41.54 24.12a5.02 5.02 0 01-3.95-1.83 6.55 6.55 0 01-1.6-4.48 6.96 6.96 0 011.66-4.58 5.3 5.3 0 014.08-1.86 4.3 4.3 0 013.7 1.92l.1-1.57h2.92V23.8h-2.93l-.1-1.76a4.52 4.52 0 01-3.88 2.08zm.76-2.88c.58 0 1.09-.16 1.57-.45.44-.32.8-.74 1.08-1.25.25-.51.38-1.12.38-1.8a3.42 3.42 0 00-1.47-3.04 2.95 2.95 0 00-3.12 0c-.44.32-.8.74-1.08 1.25a4.01 4.01 0 00-.38 1.8 3.42 3.42 0 001.47 3.04c.47.29.98.45 1.55.45zM53.45 8.46c0 .35-.06.67-.22.93-.16.25-.38.48-.67.64-.29.16-.6.22-.92.22-.32 0-.64-.06-.93-.22a1.84 1.84 0 01-.67-.64 1.82 1.82 0 01-.22-.93c0-.36.07-.68.22-.93.16-.3.39-.48.67-.64.29-.16.6-.23.93-.23a1.84 1.84 0 011.6.86 2 2 0 01.21.94zm-3.4 15.3V11.7h3.18v12.08h-3.19zm11.68-8.9v.04c-.15-.07-.35-.1-.5-.13-.2-.04-.36-.04-.55-.04-.89 0-1.56.26-2 .8-.48.55-.7 1.32-.7 2.31v5.93h-3.19V11.69h2.93l.1 1.83c.32-.64.7-1.12 1.24-1.48a3.1 3.1 0 011.81-.5c.23 0 .45.02.64.06.1.03.16.03.22.06v3.2zm1.28 8.9V6.74h3.18v6.5c.45-.58.96-1.03 1.6-1.38a5.02 5.02 0 016.08 1.31 6.55 6.55 0 011.6 4.49 6.96 6.96 0 01-1.66 4.58 5.3 5.3 0 01-4.08 1.86 4.3 4.3 0 01-3.7-1.92l-.1 1.57-2.92.03zm6.15-2.52c.57 0 1.08-.16 1.56-.45.44-.32.8-.74 1.08-1.25.26-.51.38-1.12.38-1.8 0-.67-.12-1.28-.38-1.79a3.75 3.75 0 00-1.08-1.25 2.95 2.95 0 00-3.12 0c-.45.32-.8.74-1.09 1.25a4.01 4.01 0 00-.38 1.8 3.42 3.42 0 001.47 3.04c.47.29.98.45 1.56.45zm7.51 2.53V11.69h2.93l.1 1.57a3.96 3.96 0 013.54-1.89 4.1 4.1 0 013.82 2.44c.35.76.54 1.7.54 2.75v7.24h-3.19v-6.82c0-.84-.19-1.5-.57-1.99-.38-.48-.9-.74-1.56-.74-.48 0-.9.1-1.27.32-.35.23-.64.52-.86.93a2.7 2.7 0 00-.32 1.35v6.92h-3.16zm12.52 0V6.73h3.19v6.5a4.67 4.67 0 013.73-1.89 5.02 5.02 0 013.95 1.83 6.57 6.57 0 011.59 4.48 6.95 6.95 0 01-1.66 4.58 5.3 5.3 0 01-4.08 1.86 4.3 4.3 0 01-3.7-1.92l-.09 1.57-2.93.03zm6.18-2.53c.58 0 1.09-.16 1.56-.45.45-.32.8-.74 1.09-1.25.25-.51.38-1.12.38-1.8a3.42 3.42 0 00-1.47-3.04 2.95 2.95 0 00-3.12 0c-.44.32-.8.74-1.08 1.25a3.63 3.63 0 00-.38 1.8 3.42 3.42 0 001.47 3.04c.47.29.95.45 1.55.45z">
#                </path>
#               </svg>
#              </div>
#              <div class="_17ctt5">
#               <svg fill="currentcolor" height="32" style="display:block" width="30">
#                <path d="M29.24 22.68c-.16-.39-.31-.8-.47-1.15l-.74-1.67-.03-.03c-2.2-4.8-4.55-9.68-7.04-14.48l-.1-.2c-.25-.47-.5-.99-.76-1.47-.32-.57-.63-1.18-1.14-1.76a5.3 5.3 0 00-8.2 0c-.47.58-.82 1.19-1.14 1.76-.25.52-.5 1.03-.76 1.5l-.1.2c-2.45 4.8-4.84 9.68-7.04 14.48l-.06.06c-.22.52-.48 1.06-.73 1.64-.16.35-.32.73-.48 1.15a6.8 6.8 0 007.2 9.23 8.38 8.38 0 003.18-1.1c1.3-.73 2.55-1.79 3.95-3.32 1.4 1.53 2.68 2.59 3.95 3.33A8.38 8.38 0 0022.75 32a6.79 6.79 0 006.75-5.83 5.94 5.94 0 00-.26-3.5zm-14.36 1.66c-1.72-2.2-2.84-4.22-3.22-5.95a5.2 5.2 0 01-.1-1.96c.07-.51.26-.96.52-1.34.6-.87 1.65-1.41 2.8-1.41a3.3 3.3 0 012.8 1.4c.26.4.45.84.51 1.35.1.58.06 1.25-.1 1.96-.38 1.7-1.5 3.74-3.21 5.95zm12.74 1.48a4.76 4.76 0 01-2.9 3.75c-.76.32-1.6.41-2.42.32-.8-.1-1.6-.36-2.42-.84a15.64 15.64 0 01-3.63-3.1c2.1-2.6 3.37-4.97 3.85-7.08.23-1 .26-1.9.16-2.73a5.53 5.53 0 00-.86-2.2 5.36 5.36 0 00-4.49-2.28c-1.85 0-3.5.86-4.5 2.27a5.18 5.18 0 00-.85 2.21c-.13.84-.1 1.77.16 2.73.48 2.11 1.78 4.51 3.85 7.1a14.33 14.33 0 01-3.63 3.12c-.83.48-1.62.73-2.42.83a4.76 4.76 0 01-5.32-4.07c-.1-.8-.03-1.6.29-2.5.1-.32.25-.64.41-1.02.22-.52.48-1.06.73-1.6l.04-.07c2.16-4.77 4.52-9.64 6.97-14.41l.1-.2c.25-.48.5-.99.76-1.47.26-.51.54-1 .9-1.4a3.32 3.32 0 015.09 0c.35.4.64.89.9 1.4.25.48.5 1 .76 1.47l.1.2c2.44 4.77 4.8 9.64 7 14.41l.03.03c.26.52.48 1.1.73 1.6.16.39.32.7.42 1.03.19.9.29 1.7.19 2.5z">
#                </path>
#               </svg>
#              </div>
#             </a>
#            </div>
#            <div class="_2ox3s8">
#             <div class="_1i5xg6by">
#              <div aria-labelledby="littleSearchLabel" class="_1aese7c" data-testid="little-search" role="search">
#               <span class="_krjbj" id="littleSearchLabel">
#                Start your search
#               </span>
#               <button class="_b2fxuo" data-index="0" type="button">
#                <span class="_krjbj">
#                 Location
#                </span>
#                <div class="_1g5ss3l">
#                 Queensland
#                </div>
#               </button>
#               <span class="_10u04nz">
#               </span>
#               <button class="_b2fxuo" data-index="1" type="button">
#                <span class="_krjbj">
#                 Check in / Check out
#                </span>
#                <div class="_1bv2ej4q">
#                 Add dates
#                </div>
#               </button>
#               <span class="_10u04nz">
#               </span>
#               <button class="_b2fxuo" data-index="2" type="button">
#                <span class="_krjbj">
#                 Guests
#                </span>
#                <div class="_1bv2ej4q">
#                 Add guests
#                </div>
#                <div class="_i8zuk7" data-icon="true" data-testid="little-search-icon">
#                 <svg aria-hidden="true" focusable="false" role="presentation" style="display:block;fill:none;height:12px;width:12px;stroke:currentColor;stroke-width:5.333333333333333;overflow:visible" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#                  <g fill="none">
#                   <path d="m13 24c6.0751322 0 11-4.9248678 11-11 0-6.07513225-4.9248678-11-11-11-6.07513225 0-11 4.92486775-11 11 0 6.0751322 4.92486775 11 11 11zm8-3 9 9">
#                   </path>
#                  </g>
#                 </svg>
#                </div>
#               </button>
#              </div>
#             </div>
#             <div class="_1cdxza1q">
#              <div data-nosnippet="true">
#               <div class="_1lveqk8">
#                <div>
#                 <form action="/s/all" class="_1keztfl" method="get" role="search">
#                  <fieldset class="_d206yy">
#                   <div aria-label="What can we help you find?" class="_17fy1ix" role="tablist">
#                    <label class="_3hmsj" for="search-block-tab-false-STAYS">
#                     <input aria-selected="true" checked="" class="_1ai7zse" data-testid="radio-tab-search-block-tab-false-STAYS" id="search-block-tab-false-STAYS" name="refinement_paths[]" role="tab" type="radio" value="/homes"/>
#                     <span class="_17gwvodj" data-text="true">
#                      Places to stay
#                     </span>
#                    </label>
#                    <label class="_3hmsj" for="search-block-tab-false-EXPERIENCES">
#                     <input aria-selected="false" class="_1ai7zse" data-testid="radio-tab-search-block-tab-false-EXPERIENCES" id="search-block-tab-false-EXPERIENCES" name="refinement_paths[]" role="tab" type="radio" value="/experiences"/>
#                     <span class="_17gwvodj" data-text="true">
#                      Experiences
#                     </span>
#                    </label>
#                   </div>
#                  </fieldset>
#                  <div class="_urq7mym" data-panel-bounds="true">
#                   <div class="_1c7nvmy">
#                    <div class="_1jkbosm7">
#                     <div>
#                      <div class="_mnnz9u">
#                       <label class="_koumzdh" for="bigsearch-query-detached-query">
#                        <div class="_gor68n">
#                         <div class="_1i9tpqw">
#                          Location
#                         </div>
#                         <input aria-autocomplete="list" aria-expanded="false" autocomplete="off" autocorrect="off" class="_1xq16jy" data-testid="structured-search-input-field-query" id="bigsearch-query-detached-query" name="query" placeholder="Where are you going?" required="" role="combobox" spellcheck="false" value="Queensland, Australia"/>
#                        </div>
#                       </label>
#                       <span class="_krjbj" id="Koan-query__description">
#                        Navigate forward to access suggested results
#                       </span>
#                       <span aria-atomic="true" aria-live="polite" class="_krjbj" role="status">
#                       </span>
#                      </div>
#                     </div>
#                    </div>
#                    <div class="_43mycv">
#                    </div>
#                    <div class="_1l6jpwo">
#                     <div class="_j8gg2a">
#                      <div aria-expanded="false" class="_1akb2mdw" data-testid="structured-search-input-field-split-dates-0" role="button" tabindex="0">
#                       <div class="_seuyf">
#                        <div class="_wtz1co">
#                         Check in
#                        </div>
#                        <div class="_uh2dzp">
#                         Add dates
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                     <div class="_43mycv">
#                     </div>
#                     <div class="_j8gg2a">
#                      <div aria-expanded="false" class="_1akb2mdw" data-testid="structured-search-input-field-split-dates-1" role="button" tabindex="0">
#                       <div class="_seuyf">
#                        <div class="_wtz1co">
#                         Check out
#                        </div>
#                        <div class="_uh2dzp">
#                         Add dates
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                    <div class="_43mycv">
#                    </div>
#                    <div class="_1yulsurh">
#                     <div aria-expanded="false" class="_37ivfdq" data-testid="structured-search-input-field-guests-button" role="button" tabindex="0">
#                      <div class="_seuyf">
#                       <div class="_wtz1co">
#                        Guests
#                       </div>
#                       <div class="_uh2dzp">
#                        Add guests
#                       </div>
#                      </div>
#                     </div>
#                     <div class="_w64aej">
#                      <button aria-expanded="false" class="_sxfp92z" data-testid="structured-search-input-search-button" type="button">
#                       <div class="_1hb5o3s">
#                        <div class="_14lk9e14">
#                         <svg aria-hidden="true" focusable="false" role="presentation" style="display:block;fill:none;height:16px;width:16px;stroke:currentColor;stroke-width:4;overflow:visible" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#                          <g fill="none">
#                           <path d="m13 24c6.0751322 0 11-4.9248678 11-11 0-6.07513225-4.9248678-11-11-11-6.07513225 0-11 4.92486775-11 11 0 6.0751322 4.92486775 11 11 11zm8-3 9 9">
#                           </path>
#                          </g>
#                         </svg>
#                        </div>
#                        <div class="_c5qlo1f">
#                         Search
#                        </div>
#                       </div>
#                      </button>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </form>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="_19h9w7f">
#             <nav aria-label="Main" class="_vuzcgs">
#              <div class="_176ugpa">
#               <a class="_1x6o0b9n" href="/host/homes">
#                <div class="_iglww7">
#                 Become a host
#                </div>
#               </a>
#               <div class="_1ubw29">
#                <a aria-expanded="false" aria-label="Language and currency" class="_1x6o0b9n" href="#simple-header-locale-menu-combined">
#                 <div class="_iglww7">
#                  <div aria-hidden="true" class="_z5mecy">
#                   <svg aria-hidden="true" focusable="false" role="presentation" style="display:block;height:16px;width:16px;fill:currentColor" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#                    <path d="m8.002.25a7.77 7.77 0 0 1 7.748 7.776 7.75 7.75 0 0 1 -7.521 7.72l-.246.004a7.75 7.75 0 0 1 -7.73-7.513l-.003-.245a7.75 7.75 0 0 1 7.752-7.742zm1.949 8.5h-3.903c.155 2.897 1.176 5.343 1.886 5.493l.068.007c.68-.002 1.72-2.365 1.932-5.23zm4.255 0h-2.752c-.091 1.96-.53 3.783-1.188 5.076a6.257 6.257 0 0 0 3.905-4.829zm-9.661 0h-2.75a6.257 6.257 0 0 0 3.934 5.075c-.615-1.208-1.036-2.875-1.162-4.686l-.022-.39zm1.188-6.576-.115.046a6.257 6.257 0 0 0 -3.823 5.03h2.75c.085-1.83.471-3.54 1.059-4.81zm2.262-.424c-.702.002-1.784 2.512-1.947 5.5h3.904c-.156-2.903-1.178-5.343-1.892-5.494l-.065-.007zm2.28.432.023.05c.643 1.288 1.069 3.084 1.157 5.018h2.748a6.275 6.275 0 0 0 -3.929-5.068z">
#                    </path>
#                   </svg>
#                  </div>
#                 </div>
#                </a>
#               </div>
#              </div>
#              <div class="_3hmsj">
#               <div class="_167wsvl">
#                <a aria-expanded="false" class="_1usxwsg6" data-testid="cypress-headernav-profile" href="#simple-header-profile-menu" id="field-guide-toggle">
#                 <div aria-label="Main navigation menu">
#                  <svg aria-hidden="true" focusable="false" role="presentation" style="display:block;fill:none;height:16px;width:16px;stroke:currentColor;stroke-width:3;overflow:visible" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#                   <g fill="none" fill-rule="nonzero">
#                    <path d="m2 16h28">
#                    </path>
#                    <path d="m2 24h28">
#                    </path>
#                    <path d="m2 8h28">
#                    </path>
#                   </g>
#                  </svg>
#                 </div>
#                 <div aria-hidden="true" class="_1sfnwgq">
#                  <svg aria-hidden="true" focusable="false" role="presentation" style="display:block;height:100%;width:100%;fill:currentColor" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
#                   <path d="m16 .7c-8.437 0-15.3 6.863-15.3 15.3s6.863 15.3 15.3 15.3 15.3-6.863 15.3-15.3-6.863-15.3-15.3-15.3zm0 28c-4.021 0-7.605-1.884-9.933-4.81a12.425 12.425 0 0 1 6.451-4.4 6.507 6.507 0 0 1 -3.018-5.49c0-3.584 2.916-6.5 6.5-6.5s6.5 2.916 6.5 6.5a6.513 6.513 0 0 1 -3.019 5.491 12.42 12.42 0 0 1 6.452 4.4c-2.328 2.925-5.912 4.809-9.933 4.809z">
#                   </path>
#                  </svg>
#                 </div>
#                </a>
#                <div class="_1g865qv3" data-testid="simple-header-profile-menu" id="simple-header-profile-menu" tabindex="-1">
#                 <div>
#                  <a class="_14tt8lmp" data-testid="cypress-headernav-signup" href="/signup_login">
#                   <div class="_ojs7nk">
#                    Sign up
#                   </div>
#                  </a>
#                  <a class="_1qvp8oxp" data-testid="cypress-headernav-login" href="/login">
#                   <div class="_ojs7nk">
#                    Log in
#                   </div>
#                  </a>
#                  <div class="_apke5g">
#                  </div>
#                  <a class="_1qvp8oxp" href="/host/homes">
#                   <div class="_ojs7nk">
#                    Host your home
#                   </div>
#                  </a>
#                  <a class="_1qvp8oxp" href="/host/experiences?from_nav=1">
#                   <div class="_ojs7nk">
#                    Host an experience
#                   </div>
#                  </a>
#                  <a class="_1qvp8oxp" data-no-client-routing="" href="/help">
#                   <div class="_ojs7nk">
#                    Help
#                   </div>
#                  </a>
#                 </div>
#                </div>
#                <a aria-label="Close" href="#">
#                </a>
#               </div>
#              </div>
#             </nav>
#            </div>
#           </div>
#          </header>
#          <div class="_qkr85q">
#          </div>
#         </div>
#        </div>
#        <div class="_xca6kx">
#        </div>
#        <main id="site-content" tabindex="-1">
#         <div class="_1nkqnd0" data-container="ExploreLayoutController" id="ExploreLayoutController">
#          <div aria-hidden="false" class="_10ljxo8" style="min-height:calc(100vh - 0px)">
#           <div>
#            <div class="_uhpzdny">
#             <div class="_rrw786">
#              <section>
#               <div class="_1snxcqc">
#                300+ stays
#               </div>
#               <div class="_1lbq8dg">
#                <h1 class="_14i3z6h" tabindex="-1">
#                 Stays in Queensland
#                </h1>
#               </div>
#              </section>
#             </div>
#            </div>
#            <div aria-hidden="false" class="_twmmpk">
#             <div class="_19qnt1y" data-container-name="explore" itemprop="itemList" itemscope="" itemtype="http://schema.org/ItemList">
#              <div class="_1gw6tte">
#               <div class="_uhpzdny" style="background-color:transparent">
#                <div>
#                 <div class="_1ibtygfe">
#                  <div>
#                  </div>
#                  <div id="FMP-target">
#                   <div data-testid="listings-card-row">
#                    <div class="_6htn2u">
#                     <div class="_1yj3yni">
#                      <div class="_mrriojd">
#                       <div class="_1gax70a">
#                        <h3 class="_y0ndqr">
#                         Maleny
#                        </h3>
#                       </div>
#                      </div>
#                      <div>
#                       <a aria-label="Maleny; Show (50+)" class="_gzog035" href="/s/Maleny/homes?refinement_paths%5B%5D=%2Fhomes&amp;flexible_trip_dates%5B%5D=june&amp;flexible_trip_dates%5B%5D=may&amp;flexible_trip_lengths%5B%5D=weekend_trip&amp;date_picker_type=calendar&amp;source=structured_search_input_header&amp;search_type=unknown&amp;query=Maleny&amp;place_id=ChIJ-2D-bBSHk2sRAMLe81qjAgU&amp;click_referer=t%3ASEE_ALL%7Csid%3A43eff528-4620-401b-8d96-195b6696dc38%7Cst%3ASTAYS_LARGE_AREA_DESTINATION_CAROUSELS&amp;search_mode=regular_search&amp;title_type=NONE&amp;last_search_session_id=43eff528-4620-401b-8d96-195b6696dc38">
#                        Show (50+)
#                       </a>
#                      </div>
#                     </div>
#                     <div class="_e296pg">
#                      <div class="_1ssk74kh">
#                       <div style="margin-top:0;margin-bottom:0">
#                        <div class="_p19ynwq">
#                         <div class="_1hqul550">
#                          <div class="_1ilrlnv">
#                           <div style="margin-bottom:16px">
#                            <div aria-labelledby="title_14887315" class="_e296pg" role="group">
#                             <a aria-labelledby="title_14887315" class="_1jhvjuo" href="/rooms/14887315?federated_search_id=ff0f079a-386d-4984-84a1-01bd330ee3d0" rel="noopener noreferrer" target="_blank">
#                             </a>
#                             <div class="_3x2xkx">
#                              <div class="_uae3t0w">
#                               <div class="_1mx6kqf" style="background:#484848;--dls-basecard-padding-top:66.6667%">
#                                <div class="_1szwzht">
#                                 <div class="_v0gz4uz" style="--dls-liteimage-padding-top:66.6667%">
#                                  <div class="_4626ulj">
# ...
#               Host an Experience
#              </a>
#             </li>
#             <li class="_wmuyow">
#              <a class="_o06542u" href="/help/responsible-hosting">
#               Responsible hosting
#              </a>
#             </li>
#             <li class="_wmuyow">
#              <a class="_o06542u" href="/resources">
#               Resource Centre
#              </a>
#             </li>
#             <li class="_wmuyow">
#              <a class="_o06542u" href="/help/community?s=footer">
#               Community Centre
#              </a>
#             </li>
#            </ul>
#           </section>
#           <section class="_1l3ys1i">
#            <h4 class="_tfslnm">
#             Support
#            </h4>
#            <ul class="_yuolfv">
#             <li class="_wmuyow">
#              <a class="_o06542u" href="/d/covidsafety">
#               Our COVID-19 Response
#              </a>
#             </li>
#             <li class="_wmuyow">
#              <a class="_o06542u" href="/help?from=footer">
#               Help Centre
#              </a>
#             </li>
#             <li class="_wmuyow">
#              <a class="_o06542u" href="/help/article/2701/extenuating-circumstances-policy-and-the-coronavirus-covid19">
#               Cancellation options
#              </a>
#             </li>
#             <li class="_wmuyow">
#              <a class="_o06542u" href="/neighbors">
#               Neighbourhood Support
#              </a>
#             </li>
#             <li class="_wmuyow">
#              <a class="_o06542u" href="/trust">
#               Trust &amp; Safety
#              </a>
#             </li>
#            </ul>
#           </section>
#          </div>
#          <div class="_1wsqynx">
#           <section class="_1tu1axq">
#            <div class="_1m14l43">
#             <div class="_3hmsj">
#              <div class="_jro6t0">
#               <span class="_19c5bku">
#                <a class="_1kejnocv" data-no-client-routing="true" href="/account-settings/language">
#                 <span class="_krjbj">
#                  Choose a language
#                 </span>
#                 <span class="_14tkmhr">
#                  <svg aria-hidden="true" focusable="false" role="presentation" style="display:block;height:16px;width:16px;fill:currentColor" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#                   <path d="m8.002.25a7.77 7.77 0 0 1 7.748 7.776 7.75 7.75 0 0 1 -7.521 7.72l-.246.004a7.75 7.75 0 0 1 -7.73-7.513l-.003-.245a7.75 7.75 0 0 1 7.752-7.742zm1.949 8.5h-3.903c.155 2.897 1.176 5.343 1.886 5.493l.068.007c.68-.002 1.72-2.365 1.932-5.23zm4.255 0h-2.752c-.091 1.96-.53 3.783-1.188 5.076a6.257 6.257 0 0 0 3.905-4.829zm-9.661 0h-2.75a6.257 6.257 0 0 0 3.934 5.075c-.615-1.208-1.036-2.875-1.162-4.686l-.022-.39zm1.188-6.576-.115.046a6.257 6.257 0 0 0 -3.823 5.03h2.75c.085-1.83.471-3.54 1.059-4.81zm2.262-.424c-.702.002-1.784 2.512-1.947 5.5h3.904c-.156-2.903-1.178-5.343-1.892-5.494l-.065-.007zm2.28.432.023.05c.643 1.288 1.069 3.084 1.157 5.018h2.748a6.275 6.275 0 0 0 -3.929-5.068z">
#                   </path>
#                  </svg>
#                 </span>
#                 <span class="_bjxj6b">
#                  English (AU)
#                 </span>
#                </a>
#               </span>
#               <span class="_19c5bku">
#                <a class="_1kejnocv" data-no-client-routing="true" href="/account-settings/currency">
#                 <span class="_krjbj">
#                  Choose a currency
#                 </span>
#                 <span class="_14tkmhr">
#                  $
#                 </span>
#                 <span class="_bjxj6b">
#                  AUD
#                 </span>
#                </a>
#               </span>
#              </div>
#             </div>
#             <div class="_2ms5qb">
#              <ul class="_115qwnm">
#               <li class="_kdkpwk">
#                <a class="_s7cvp1u" href="https://www.facebook.com/AirbnbAustralia" rel="noopener noreferrer" target="_blank">
#                 <svg aria-hidden="false" aria-label="Navigate to Facebook" focusable="false" role="img" style="height:18px;width:18px;display:block;fill:currentColor" viewbox="0 0 32 32">
#                  <path d="m8 14.41v-4.17c0-.42.35-.81.77-.81h2.52v-2.08c0-4.84 2.48-7.31 7.42-7.35 1.65 0 3.22.21 4.69.64.46.14.63.42.6.88l-.56 4.06c-.04.18-.14.35-.32.53-.21.11-.42.18-.63.14-.88-.25-1.78-.35-2.8-.35-1.4 0-1.61.28-1.61 1.73v1.8h4.52c.42 0 .81.42.81.88l-.35 4.17c0 .42-.35.71-.77.71h-4.21v16c0 .42-.35.81-.77.81h-5.21c-.42 0-.8-.39-.8-.81v-16h-2.52a.78.78 0 0 1 -.78-.78" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                </a>
#               </li>
#               <li class="_kdkpwk">
#                <a class="_s7cvp1u" href="https://twitter.com/airbnb_au" rel="noopener noreferrer" target="_blank">
#                 <svg aria-hidden="false" aria-label="Navigate to Twitter" focusable="false" role="img" style="height:18px;width:18px;display:block;fill:currentColor" viewbox="0 0 32 32">
#                  <path d="m31 6.36c-1.16.49-2.32.82-3.55.95 1.29-.76 2.22-1.87 2.72-3.38a13.05 13.05 0 0 1 -3.91 1.51c-1.23-1.28-2.75-1.94-4.51-1.94-3.41 0-6.17 2.73-6.17 6.12 0 .49.07.95.17 1.38-4.94-.23-9.51-2.6-12.66-6.38-.56.95-.86 1.97-.86 3.09 0 2.07 1.03 3.91 2.75 5.06-1-.03-1.92-.3-2.82-.76v.07c0 2.89 2.12 5.42 4.94 5.98-.63.17-1.16.23-1.62.23-.3 0-.7-.03-1.13-.13a6.07 6.07 0 0 0 5.74 4.24c-2.22 1.74-4.78 2.63-7.66 2.63-.56 0-1.06-.03-1.43-.1 2.85 1.84 6 2.76 9.41 2.76 7.29 0 12.83-4.01 15.51-9.3 1.36-2.66 2.02-5.36 2.02-8.09v-.46c-.03-.17-.03-.3-.03-.33a12.66 12.66 0 0 0 3.09-3.16" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                </a>
#               </li>
#               <li class="_kdkpwk">
#                <a class="_s7cvp1u" href="https://instagram.com/airbnb" rel="noopener noreferrer" target="_blank">
#                 <svg aria-hidden="false" aria-label="Navigate to Instagram" focusable="false" role="img" style="height:18px;width:18px;display:block;fill:currentColor" viewbox="0 0 24 24">
#                  <path d="m23.09.91c-.61-.61-1.33-.91-2.17-.91h-17.84c-.85 0-1.57.3-2.17.91s-.91 1.33-.91 2.17v17.84c0 .85.3 1.57.91 2.17s1.33.91 2.17.91h17.84c.85 0 1.57-.3 2.17-.91s.91-1.33.91-2.17v-17.84c0-.85-.3-1.57-.91-2.17zm-14.48 7.74c.94-.91 2.08-1.37 3.4-1.37 1.33 0 2.47.46 3.41 1.37s1.41 2.01 1.41 3.3-.47 2.39-1.41 3.3-2.08 1.37-3.41 1.37c-1.32 0-2.46-.46-3.4-1.37s-1.41-2.01-1.41-3.3.47-2.39 1.41-3.3zm12.66 11.63c0 .27-.09.5-.28.68a.92.92 0 0 1 -.67.28h-16.7a.93.93 0 0 1 -.68-.28.92.92 0 0 1 -.27-.68v-10.13h2.2a6.74 6.74 0 0 0 -.31 2.05c0 2 .73 3.71 2.19 5.12s3.21 2.12 5.27 2.12a7.5 7.5 0 0 0 3.75-.97 7.29 7.29 0 0 0 2.72-2.63 6.93 6.93 0 0 0 1-3.63c0-.71-.11-1.39-.31-2.05h2.11v10.12zm0-13.95c0 .3-.11.56-.31.77a1.05 1.05 0 0 1 -.77.31h-2.72c-.3 0-.56-.11-.77-.31a1.05 1.05 0 0 1 -.31-.77v-2.58c0-.29.11-.54.31-.76s.47-.32.77-.32h2.72c.3 0 .56.11.77.32s.31.47.31.76z" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class="_zyu73r">
#             <div class="_pd8gea">
#              <div class="_9q359r">
#               <div class="_1br4kkl" dir="ltr">
#                © 2021 Airbnb, Inc.
#               </div>
#               <div class="_opoa3c">
#                <span class="_j8ldew">
#                 <span aria-hidden="true" class="_10wqwyj">
#                  ·
#                 </span>
#                </span>
#                <a class="_o06542u" href="/terms/privacy_policy">
#                 Privacy
#                </a>
#                <span aria-hidden="true" class="_10wqwyj">
#                 ·
#                </span>
#                <a class="_o06542u" href="/terms">
#                 Terms
#                </a>
#                <span aria-hidden="true" class="_10wqwyj">
#                 ·
#                </span>
#                <a class="_o06542u" href="/sitemaps/v2">
#                 Sitemap
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </section>
#          </div>
#         </div>
#        </footer>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script data-route-config="true" id="data-route-config" type="application/json">
#    "default"
#   </script>
#   <script data-locale="true" id="data-locale" type="application/json">
#    "en-AU"
#   </script>
#   <script data-webpack="true" id="data-webpack" type="application/json">
#    {"renderedAsyncChunkIds":["16e8","d54e","d687","16e8","22fe","df3e","c682","ab1e","60bb","16e8","5f89","0740","ef61","67a2","1614","b9c5","9ee0","8b75","6297","bea9","2266","34b05","053d","d74d","775c","60bb","16e8","b338","0421","1940","1591","60bb","16e8","b338","f4f6","f8fc","0421","1940","eb06","e091","16e8","22fe","0811","60bb","c32d","16e8","5f89","3e42","ef61","67a2","d2a5","b338","6285","2824","9ee0","0421","b45b","7ed2","bea9","34b0","7a36","8dd3","b3c3","8d13","a7ed","ac50","b12d","8359","a315","60bb","16e8","e301","f9cc","5bb5","a084","9698","0128","2b8e","c232","d465","6215","21bf","16e8","0149","3c2a","60bb","16e8","7254","d235","c46c"]}
#   </script>
#   <script data-state="true" id="data-state" type="application/json">
#    {"IS_DEV":false,"HYPERLOOP_ENV":"core-guest-loop-production","IS_ADMIN":false,"behavioralUid":"1619678116_ZTg2OTRkODk3MDU2","i18nInit":{"locale":"en-AU","base_direction":"ltr","language":"en","moment_locale":"en-au","country":"AU","tld_country":"AU","current_locale_name":"English (AU)","currencies":[{"code":"AED","id":"AED","name":"United Arab Emirates Dirham","symbol":"&#1583;.&#1573;","unicode_symbol":"ﺩ.ﺇ","show_currency_explicitly":false,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":false,"position":"before","space_between_price_and_symbol":false},{"code":"ARS","id":"ARS","name":"Argentinian Pesos","symbol":"$","unicode_symbol":"$","show_currency_explicitly":true,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":false,"position":"before","space_between_price_and_symbol":false},{"code":"AUD","id":"AUD","name":"Australian Dollars","symbol":"$","unicode_symbol":"$","show_currency_explicitly":true,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":false,"position":"before","space_between_price_and_symbol":false},{"code":"BGN","id":"BGN","name":"Bulgarian Leva","symbol":"&#1083;&#1074;","unicode_symbol":"лв","show_currency_explicitly":false,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":false,"position":"before","space_between_price_and_symbol":false},{"code":"BRL","id":"BRL","name":"Brazilian Reais","symbol":"R$","unicode_symbol":"R$","show_currency_explicitly":false,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":false,"position":"before","space_between_price_and_symbol":false},{"code":"CAD","id":"CAD","name":"Canadian Dollar","symbol":"$","unicode_symbol":"$","show_currency_explicitly":true,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":false,"position":"before","space_between_price_and_symbol":false},{"code":"CHF","id":"CHF","name":"Swiss Francs","symbol":"CHF","unicode_symbol":"CHF","show_currency_explicitly":false,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":true,"position":"after","space_between_price_and_symbol":true},{"code":"CLP","id":"CLP","name":"Chilean Pesos","symbol":"$","unicode_symbol":"$","show_currency_explicitly":true,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":false,"position":"before","space_between_price_and_symbol":false},{"code":"CNY","id":"CNY","name":"Chinese Yuan","symbol":"&#65509;","unicode_symbol":"￥","show_currency_explicitly":false,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":false,"position":"before","space_between_price_and_symbol":false},{"code":"COP","id":"COP","name":"Columbian Pesos","symbol":"$","unicode_symbol":"$","show_currency_explicitly":true,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":false,"position":"before","space_between_price_and_symbol":false},{"code":"CRC","id":"CRC","name":"Colon","symbol":"&#8353;","unicode_symbol":"₡","show_currency_explicitly":false,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":false,"position":"before","space_between_price_and_symbol":false},{"code":"CZK","id":"CZK","name":"Czech Koruny","symbol":"&#75;&#269;","unicode_symbol":"Kč","show_currency_explicitly":false,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":false,"position":"before","space_between_price_and_symbol":false},{"code":"DKK","id":"DKK","name":"Danish Kroner","symbol":"kr","unicode_symbol":"kr","show_currency_explicitly":true,"explicit_currency_not_aesthetic":true,"hide_code_if_symbol_shown":false,"position":"after","space_between_price_and_symbol":true},{"code":"EUR","id":"EUR","name":"Euro","symbol":"&euro;","unicode_symbol":"€","show_currency_explicitly":false,"explicit_currency_not_aesthetic":false,"hide_code_if_symbol_shown":false,"position":"special","space_between_price_and_symbol":false},{"code":"GBP","id":"GBP","name":"Pounds Sterling","symbol":"&pound;","unicode_symbol":"£","show_currency_explicitly":false,"explicit_currency_no ...
#   </script>
#   <script data-apollo-state="true" id="data-apollo-state" type="application/json">
#    {}
#   </script>
#   <script data-aphrodite-css="true" id="data-aphrodite-css" type="application/json">
#    ["_16grqhk","_siy8gh","_xca6kx","_1gw6tte","_1egkn2c4","_fbarm7d","_otdka","_2ox3s8","_19h9w7f","_qkr85q","_o6689fn","_1grlqto","_17ctt5","_1i5xg6by","_1cdxza1q","_i8zuk7","_1aese7c","_b2fxuo","_1g5ss3l","_10u04nz","_1bv2ej4q","_krjbj","_1lveqk8","_1jkbosm7","_1keztfl","_urq7mym","_1c7nvmy","_d206yy","_17fy1ix","_3hmsj","_1ai7zse","_17gwvodj","_mnnz9u","_koumzdh","_gor68n","_1i9tpqw","_1xq16jy","_43mycv","_1l6jpwo","_j8gg2a","_1akb2mdw","_seuyf","_wtz1co","_uh2dzp","_1yulsurh","_37ivfdq","_w64aej","_sxfp92z","_1hb5o3s","_14lk9e14","_c5qlo1f","_vuzcgs","_176ugpa","_1x6o0b9n","_iglww7","_1ubw29","_z5mecy","_167wsvl","_1usxwsg6","_1sfnwgq","_1g865qv3","_14tt8lmp","_ojs7nk","_1qvp8oxp","_apke5g","_1nkqnd0","_10ljxo8","_twmmpk","_uhpzdny","_rrw786","_1snxcqc","_1lbq8dg","_14i3z6h","_19qnt1y","_1ibtygfe","_1ilrlnv","_1ssk74kh","_p19ynwq","_6htn2u","_1yj3yni","_mrriojd","_e296pg","_1gax70a","_1qbrhv4","_y0ndqr","_gzog035","_1hqul550","_1jhvjuo","_3x2xkx","_r04ms0","_uae3t0w","_1mx6kqf","_1szwzht","_91slf2a","_v0gz4uz","_10xjrv2u","_4626ulj","_5ogqp7","_zjunba","_1gehwvz","_1xzy2","_3foscvf","_11el2tbg","_1coc2b2","_1tyrh76","_ufoy4t","_177jc1o","_1tanv1h","keyframe_18jn58a","_h4ay9r7","_18khxk1","_1l2mls3","_11ry7lz","_a7a5sx","_1dmgzapx","_1lmky0y","_194e2vt2","_5kaapu","_1isz8pdq","_csnjx6","_4gelgl","_1klfbd5m","_olc9rf0","_ujf3ni","_1asxs4e","_1c02cnn","_1875dx","_ebe4pze","_wgmchy","_p03egf","_1vk19cb","_1jbrhd2l","_1vi6dq1","_1tp1o9s","_14aq8wg","_1i13tcg","_pihus2","_6tbg2q","_1h6n1zu","_aov0j6","_115dvcs","_1b3pcll","_1mafdrow","_gig1e7","_fhph4u","_8ssblpx","_8s3ctt","_mm360j","_1nz9l7j","_12oal24","_r6zroz","_1mleygo","_h34mg6","_1hxyyw3","_ls0e43","_b14dlit","_bzh5lkq","_12xcxtl","_kqh46o","_10fy1f8","_1imikuk8","_mjvmnj","_1gi6jw3f","_7qp4lh","_1px14rv","_99vlue","_jro6t0","_1tz7url","_15k0tg7v","_1y623pm","_3bjjf5","_za9j7e","_1h559tl","_vzrndj","_ebw3fz9","_gm11ak","_r16tng","_1uerx5s","_zdqf8l","_1tywmry","_154s4za2","_fyxf74","_1wsqynx","_1l3ys1i","_tfslnm","_yuolfv","_wmuyow","_o06542u","_1tu1axq","_1m14l43","_2ms5qb","_zyu73r","_19c5bku","_14tkmhr","_bjxj6b","_1kejnocv","_115qwnm","_kdkpwk","_s7cvp1u","_j8ldew","_pd8gea","_9q359r","_1br4kkl","_opoa3c","_10wqwyj"]
#   </script>
#   <script data-is-metro="true" id="data-is-metro" type="application/json">
#    false
#   </script>
#   <div id="field-guide-container">
#   </div>
#   <style>
#    #fb_xdm_frame_https{visibility:hidden}
#   </style>
#   <div id="fb-root">
#   </div>
#   <div id="authModals">
#   </div>
#   <script data-deferred-state="true" id="data-deferred-state" type="application/json">
#    {"niobeMinimalClientData":[]}
#   </script>
#  </body>
# </html>

# %% [markdown]
# # 4. Inspect elements ( that will be useful for airbnb analytics)

# %%
#Press F12 on the web url

# %% [markdown]
# # 5. Scrape 1 element

# %%
listings=soup.find_all('div','_gig1e7')

# %%
# I can also extract the child tag
#listings = soup.find_all('div','_8s3ctt')

# %%
listings[0]
# Out:
# <div class="_gig1e7"><div itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><meta content="Vintage van 'Stevie' w. Mt views, food &amp; hot tub - null - Pumpenbil" itemprop="name"/><meta content="1" itemprop="position"/><meta content="www.airbnb.com.au/rooms/24088196?previous_page_section_name=1000" itemprop="url"/><div><div><div aria-labelledby="title_24088196" class="_8s3ctt" role="group"><a aria-labelledby="title_24088196" class="_mm360j" href="/rooms/24088196?previous_page_section_name=1000&amp;federated_search_id=ff0f079a-386d-4984-84a1-01bd330ee3d0" rel="noopener noreferrer" target="listing_24088196"></a><div class="_1nz9l7j"><div class="_uae3t0w"><div class="_1mx6kqf" style="background:#484848;--dls-basecard-padding-top:66.6667%"><div class="_1szwzht"><div class="_v0gz4uz" style="--dls-liteimage-padding-top:66.6667%"><div class="_4626ulj"><img alt="" aria-hidden="true" class="_91slf2a" data-original-uri="https://a0.muscache.com/im/pictures/564a09e5-a11c-4a47-b3da-85073de99748.jpg?im_w=720" src="https://a0.muscache.com/im/pictures/564a09e5-a11c-4a47-b3da-85073de99748.jpg?im_w=720" style="object-fit:cover"/><div class="_10xjrv2u" style="background-image:url(https://a0.muscache.com/im/pictures/564a09e5-a11c-4a47-b3da-85073de99748.jpg?im_w=720);background-size:cover"></div></div></div></div></div><div class="_5ogqp7"><div class="_zjunba" style="padding:8px"><div><div class="_1tyrh76" style="background-color:rgba(255, 255, 255, 0.95);border:0.5px solid rgba(0, 0, 0, 0.2);color:#222222"><div class="_ufoy4t">SUPERHOST</div></div></div></div><div class="_1xzy2"><div class="_3foscvf"><button aria-label="Previous image" class="_177jc1o" type="button"><span class="_3hmsj"><svg aria-hidden="true" focusable="false" role="presentation" style="height:10px;width:10px;display:block;fill:currentColor" viewbox="0 0 16 16"><path d="m10.8 16c-.4 0-.7-.1-.9-.4l-6.8-6.7c-.5-.5-.5-1.3 0-1.8l6.8-6.7c.5-.5 1.2-.5 1.7 0s .5 1.2 0 1.7l-5.8 5.9 5.8 5.9c.5.5.5 1.2 0 1.7-.2.3-.5.4-.8.4"></path></svg></span></button></div><div class="_11el2tbg"><button aria-label="Next image" class="_177jc1o" type="button"><span class="_3hmsj"><svg aria-hidden="true" focusable="false" role="presentation" style="height:10px;width:10px;display:block;fill:currentColor" viewbox="0 0 16 16"><path d="m5.3 16c .3 0 .6-.1.8-.4l6.8-6.7c.5-.5.5-1.3 0-1.8l-6.8-6.7c-.5-.5-1.2-.5-1.7 0s-.5 1.2 0 1.7l5.8 5.9-5.8 5.9c-.5.5-.5 1.2 0 1.7.2.3.5.4.9.4"></path></svg></span></button></div></div><div class="_1coc2b2"></div></div></div></div><div class="_12oal24"><div class="_r6zroz"><div class="_1mleygo"><div class="_1tanv1h" style="margin-bottom:4px"><div class="_b14dlit">Campervan/RV in Pumpenbil</div></div><div class="_5kaapu"><span class="_bzh5lkq" id="title_24088196" style="line-height:24px;max-height:24px;overflow:hidden;text-overflow:ellipsis;display:-webkit-box;-webkit-line-clamp:1;-webkit-box-orient:vertical">Vintage van 'Stevie' w. Mt views, food &amp; hot tub</span></div></div></div><div class="_12xcxtl" style="margin-top:11px;width:32px"></div><div class="_kqh46o" style="margin-top:9px"><span class="_3hmsj">2 guests</span><span aria-hidden="true"> · </span><span class="_3hmsj">1 bedroom</span><span aria-hidden="true"> · </span><span class="_3hmsj">1 bed</span><span aria-hidden="true"> · </span><span class="_3hmsj">1 bath</span></div><div class="_kqh46o" style="margin-top:4px"><span class="_3hmsj">Free parking</span><span aria-hidden="true"> · </span><span class="_3hmsj">Wi-Fi</span></div><div class="_h34mg6"><div class="_1hxyyw3"><span aria-label="Rating 4.97 out of 5; 33 reviews" class="_18khxk1" role="img"><span class="_1l2mls3"><svg aria-hidden="true" focusable="false" role="presentation" style="height:14px;width:14px;fill:currentColor" viewbox="0 0 1000 1000"><path d="M972 380c9 28 2 50-20 67L725 619l87 280c11 39-18 75-54 75-12 0-23-4-33-12L499 790 273 962a58 58 0 0 1-78-12 50 50 0 0 1-8-51l86-278L46 447c-21-17-28-39-19-67 8-24 29-40 52-40h280l87 ...

# %%
#extract the link to the first listing(anchor tag), extract the url link itself
listings[0].find_all('a')[0].get('href')
# Out:
# '/rooms/24088196?previous_page_section_name=1000&federated_search_id=ff0f079a-386d-4984-84a1-01bd330ee3d0'

# %%
#extract the text that the listing holds
listings[0].get_text()
# Out:
# "SUPERHOSTCampervan/RV in PumpenbilVintage van 'Stevie' w. Mt views, food & hot tub2 guests · 1 bedroom · 1 bed · 1 bathFree parking · Wi-Fi4.97\xa0(33 reviews)$233 AUD/ night$233 AUD per night"

# %% [markdown]
# # 6. Inspect all data elements on search page

# %%
# url: tag=a, get = href
# name: tag=div, class=_hxt6u1e, get=aria-label
# header: tag=div, class= _b14dlit

# %% [markdown]
# # 7. Write a scraping function

# %%
# My first iteration 

def extract_basic_features(listing_html):
    features_dict = {}
    
    url = listing_html.find('a').get('href')
    name = listing_html.find("div",{"class":"_5kaapu"}).get_text() #get('aria-label') does not work
    header = listing_html.find("div",{"class":"_b14dlit"}).get_text()
    price = listing_html.find("span",{"class":"_olc9rf0"}).get_text()
    
    features_dict['url'] = url
    features_dict['name']= name
    features_dict['header'] = header
    features_dict['price'] = price
    
    return features_dict

# %%
extract_basic_features(listings[0])
# Out:
# {'url': '/rooms/36945292?previous_page_section_name=1000&federated_search_id=382d21b6-9a23-4063-a40e-c88ffbe85642',
#  'name': 'Spring Haven Kuranda – Rainforest Garden Retreat',
#  'header': 'Entire cabin in Kuranda',
#  'price': '$150 AUD'}

# %%
# if the tag is not found? e.g.:
listings[0].find('b').get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-6eed241938b4> in <module>
#       1 # if the tag is not found? e.g.:
# ----> 2 listings[0].find('b').get_text()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
#Second Iteration ( to overcome issue above):
def extract_basic_features(listing_html):
    features_dict= {}
    
    try:
        url=listing_html.find('b').get('href')
    except:
        url= 'empty'
    try:
        name = listing_html.find("div",{"class":"_5kaapu"}).get_text()
    except:
        name = 'empty'
    try: header = listing_html.find("div",{"class":"_b14dlit"}).text
    except:
        header = 'empty'

    features_dict['url'] = url
    features_dict['name']= name
    features_dict['header'] = header
    
    return features_dict

# %%
# demonstrates that at least my function won't break if it cannot find a class stated
extract_basic_features(listings[0])
# Out:
# {'url': 'empty',
#  'name': "Vintage van 'Stevie' w. Mt views, food & hot tub",
#  'header': 'Campervan/RV in Pumpenbil'}

# %%
# too many separate extractions! create a dictonary to specify all the elements I wish to scrape
rules_search_page = {
    'url':{'tag':'a', 'get':'href'},
    'name':{'tag':'div','class':'_5kaapu'},
    'header':{'tag':'div', 'class':'_b14dlit'},
    'rooms':{'tag':'div', 'class':'_kqh46o' },
    'facilities':{'tag':'div', 'class':'_kqh46o', 'order':1},
    'rating_n_reviews':{'tag':'a', 'class':'__1jhvjuo', 'get':'href'},
    'price':{'tag':'span', 'class':'_olc9rf0'},
    'superhost':{'tag':'div','class':'_ufoy4t'}
    
    }

# %%
# Third iteration (rewrite the function so it understands the dictionary created above)
# 3 steps to writing the function

def extract_element(listing_html,params):

    # 1. Find the right tag
    if 'class' in params:
        elements_found = listing_html.find_all(params['tag'], params['class'])
    else:
        elements_found = listing_html.find_all(params['tag'])
        
    # 2. Extract the right element
    tag_order = params.get('order',0)
    element = elements_found[tag_order]
    
    # 3. Get text
    if 'get' in params:
        output = element.get(params['get'])
    else:
        output = element.get_text()
        
    return output

# %%
print(extract_element(listings[0], rules_search_page['header']))
print(extract_element(listings[0], rules_search_page['url']))
# Out:
# Entire cabin in Kuranda
# /rooms/36945292?previous_page_section_name=1000&federated_search_id=382d21b6-9a23-4063-a40e-c88ffbe85642

# %%
# now iterate through each feature I want to extract
for feature in rules_search_page:
    try:
        print(f"{feature}:{extract_element(listings[0], rules_search_page[feature])}")
    except:
        print(f"{feature}:empty")
# Out:
# url:/rooms/24088196?previous_page_section_name=1000&federated_search_id=ff0f079a-386d-4984-84a1-01bd330ee3d0
# name:Vintage van 'Stevie' w. Mt views, food & hot tub
# header:Campervan/RV in Pumpenbil
# rooms:2 guests · 1 bedroom · 1 bed · 1 bath
# facilities:Free parking · Wi-Fi
# rating_n_reviews:empty
# price:$233 AUD
# superhost:SUPERHOST

# %% [markdown]
# # Completed extracting features from an airbnb listing (:

# %% [markdown]
# # 8. Explore pagination

# %%
#observe how url changes when clicking on each webpage of listings
# Page 1: https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click
# Page 2: https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&source=structured_search_input_header&search_type=pagination&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&federated_search_session_id=5cfc0f7e-826a-41a2-8a3f-8c2e22cff802&items_offset=20&section_offset=6
# Page 3: https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&source=structured_search_input_header&search_type=pagination&ne_lat=-13.627010389820814&ne_lng=160.0967327582215&sw_lat=-31.13029290215115&sw_lng=138.97689022892462&zoom=5&search_by_map=true&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&federated_search_session_id=2ea30166-33ed-44aa-b66a-541655cc00e4&items_offset=40&section_offset=6

# %%
airbnb_url
# Out:
# 'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click'

# %%
# Now write the function which extracts the listings
def get_listings(search_page):
    soup = BeautifulSoup(requests.get(search_page).content, 'html.parser')
    listings = soup.find_all('div','_gig1e7')
    
    return listings

# %%
# check if it works
len(get_listings(airbnb_url))
# Out:
# 20

# %%
# now try it on second page
url_2 = airbnb_url + '&items_offset=20'
len(get_listings(url_2))
# Out:
# 20

# %%
# double check the content of url_2 if the data is there
print(extract_element(get_listings(airbnb_url)[0],rules_search_page['name']))
print(extract_element(get_listings(url_2)[0], rules_search_page['name']))
# Out:
# Noosa Hinterland Hideaway 1
# Luxury Glamping at Kanimbia in Obi Obi

# %% [markdown]
# # 9. Collect all urls

# %%
# iterate through all 15 pages
all_listings = []
for  i in range(15):
    offset = 20 * i
    url_2 = airbnb_url + '&items_offset={offset}'
    new_listings = get_listings(url_2)
    all_listings.extend(new_listings)
    
    #check if it's scraping
    print(len(all_listings))
# Out:
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300

# %%
# if airbnb or any other website stops you from scraping, could try adding a time function.
#import time
#at the end of the loop, add
#time.sleep(2)

# %%
# another check worth doing
print(extract_element(all_listings[113], rules_search_page['name']))
# Out:
# Calypso Resort Studio 444

# %% [markdown]
# # 10. Scrape all search pages

# %% [markdown]
# ### 1. Build all urls
# ### 2. Iteratively scrape them

# %%
# 1. Build all urls
def build_urls(main_url, listings_per_page=20, pages_per_location=15):
        url_list = []
        for i in range(pages_per_location):
            offset = listings_per_page * i
            url_pagination = main_url + f'&items_offset={offset}'
            url_list.append(url_pagination)
            
        return url_list

# %%
# safe function to extract all features from one page without throwing errors

def extract_page_features(soup,rules):
    features_dict = {}
    for feature in rules:
        try:
            features_dict[feature] = extract_element(soup, rules[feature])
        except:
            features_dict[feature] = 'empty' 
    return features_dict

# %%
# 2. Iteratively scrape pages
def process_search_pages(url_list):
    features_list = []
    for page in url_list:
        listings = get_listings(page)
        for listing in listings:
            features = extract_page_features(listing, rules_search_page)
            features_list.append(features)
            
    return features_list

# %%
# build a list of urls
url_list = build_urls(airbnb_url)

# %%
url_list
# Out:
# ['https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=0',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=20',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=40',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=60',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=80',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=100',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=120',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=140',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=160',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=180',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=200',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=220',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=240',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=260',
#  'https://www.airbnb.com.au/s/Queensland--Australia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=june&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Queensland%2C%20Australia&place_id=ChIJ_dxieiTf1GsRmb4SdiLQ8vU&source=structured_search_input_header&search_type=autocomplete_click&items_offset=280']

# %%
# try the function for one page
base_features = process_search_pages(url_list[:1])

# %%
base_features
# Out:
# [{'url': '/rooms/17503019?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'Cabarita headland townhouse(2 bedrooms)',
#   'header': 'Entire townhouse in Bogangar',
#   'rooms': '5 guests · 2 bedrooms · 2 beds · 1 bath',
#   'facilities': 'Kitchen · Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$94 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/42819014?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'COSY COMFORT - On The Noosa River',
#   'header': 'Entire guest suite in Noosaville',
#   'rooms': '2 guests · 1 bedroom · 1 bed · 1 bath',
#   'facilities': 'Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$110 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/48739682?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'OtherWorld Residence Byron Bay',
#   'header': 'Entire loft in Byron Bay',
#   'rooms': '4 guests · 1 bedroom · 1 bed · 1 bath',
#   'facilities': 'Kitchen · Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$90 AUD',
#   'superhost': 'empty'},
#  {'url': '/rooms/49413054?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'DHR U123 💎The Classic @ Dolphin Heads💎',
#   'header': 'Entire apartment in Dolphin Heads',
#   'rooms': '3 guests · Studio · 2 beds · 1 bath',
#   'facilities': 'Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$56 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/31156963?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'Comfortable private space in central location',
#   'header': 'Private room in Labrador',
#   'rooms': '1 guest · Studio · 1 bed · 1 private bath',
#   'facilities': 'Kitchen · Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$30 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/18011082?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'Maleny: "The Bower" - \'couple\'s cabin\'',
#   'header': 'Entire cabin in Wootha',
#   'rooms': '2 guests · 1 bedroom · 1 bed · 1 bath',
#   'facilities': 'Kitchen · Free parking · Wi-Fi · Indoor fireplace',
#   'rating_n_reviews': 'empty',
#   'price': '$154 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/46933521?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'In the heart of Mackay with everything near',
#   'header': 'Private room in Mackay',
#   'rooms': '2 guests · 1 bedroom · 1.5 shared baths',
#   'facilities': 'Kitchen · Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$45 AUD',
#   'superhost': 'empty'},
#  {'url': '/rooms/37661938?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'Romantic, Dog Friendly, Spa, Fireplace, Waterviews',
#   'header': 'Entire cottage in MacLeay Island',
#   'rooms': '4 guests · 1 bedroom · 2 beds · 1 bath',
#   'facilities': 'Kitchen · Free parking · Indoor fireplace',
#   'rating_n_reviews': 'empty',
#   'price': '$225 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/29806912?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': "'Seldom Inn' - Mudjimba Beach",
#   'header': 'Entire guest suite in Mudjimba',
#   'rooms': '2 guests · Studio · 1 bed · 1 bath',
#   'facilities': 'Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$57 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/43536201?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'Calypso Plaza Resort Unit 139',
#   'header': 'Entire apartment in Coolangatta',
#   'rooms': '3 guests · 1 bedroom · 2 beds · 1 bath',
#   'facilities': 'Kitchen · Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$115 AUD',
#   'superhost': 'empty'},
#  {'url': '/rooms/27065432?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'Tallaringa Private Luxury Camping',
#   'header': 'Tent in Nunderi',
#   'rooms': '4 guests · 1 bedroom · 1 bed · 1 bath',
#   'facilities': 'Kitchen · Free parking',
#   'rating_n_reviews': 'empty',
#   'price': '$305 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/46400006?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'Sea Temple 2 Bedroom Balcony Penthouse Apartment',
#   'header': 'Entire apartment in Craiglie',
#   'rooms': '4 guests · 2 bedrooms · 2 beds · 1 bath',
#   'facilities': 'Kitchen · Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$195 AUD',
#   'superhost': 'empty'},
#  {'url': '/rooms/46083664?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'Allamanda U2,  - Awesome Location -',
#   'header': 'Entire apartment in Caloundra',
#   'rooms': '4 guests · 2 bedrooms · 2 beds · 2 baths',
#   'facilities': 'Kitchen · Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$117 AUD',
#   'superhost': 'empty'},
#  {'url': '/rooms/25473371?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'SKYHAVEN  SANCTUARY',
#   'header': 'Tent in Tallebudgera Valley',
#   'rooms': '2 guests · 1 bedroom · 1 bed · 1 bath',
#   'facilities': 'Kitchen · Free parking',
#   'rating_n_reviews': 'empty',
#   'price': '$245 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/35981727?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'Luxe Private Retreat ~ Coffee, Wifi & Netflix',
#   'header': 'Tiny house in Burleigh Heads',
#   'rooms': '2 guests · Studio · 1 bed · 1 bath',
#   'facilities': 'Kitchen · Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$85 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/7747567?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'The Cosy Bungalow - more than just a private room!',
#   'header': 'Entire guest suite in Miallo',
#   'rooms': '2 guests · 1 bedroom · 1 bed · 1 bath',
#   'facilities': 'Kitchen · Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$89 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/1803192?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'French Style Bed&Breakfast on the Gold Coast',
#   'header': 'Entire guest suite in Tugun',
#   'rooms': '2 guests · 1 bedroom · 1 bed · 1 bath',
#   'facilities': 'Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$88 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/33524474?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': '❤️Private Rainforest Cottage within reach of beach',
#   'header': 'Entire cottage in Cooloolabin',
#   'rooms': '2 guests · Studio · 1 bed · 1 bath',
#   'facilities': 'Kitchen · Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$84 AUD',
#   'superhost': 'empty'},
#  {'url': '/rooms/35632424?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'Tranquility, Nature & Seclusion - rural getaway!',
#   'header': 'Entire cabin in Tintenbar',
#   'rooms': '2 guests · 1 bedroom · 2 beds · 1 bath',
#   'facilities': 'Kitchen · Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$115 AUD',
#   'superhost': 'SUPERHOST'},
#  {'url': '/rooms/43173922?previous_page_section_name=1000&federated_search_id=9ba10514-b727-404d-b035-519c3c4186f9',
#   'name': 'D & A Airbnb with a jungle retreat in Cooran',
#   'header': 'Entire townhouse in Cooran',
#   'rooms': '2 guests · 1 bedroom · 1 bed · 1.5 baths',
#   'facilities': 'Kitchen · Free parking · Wi-Fi',
#   'rating_n_reviews': 'empty',
#   'price': '$90 AUD',
#   'superhost': 'SUPERHOST'}]

# %% [markdown]
# # Next Steps:
#
# ## 1. Scrape data from detailed pages since search pages are dynamic
#
# ## 2. ML models
# ### + clean the data
# ### + build features
# ### + fill empty values
